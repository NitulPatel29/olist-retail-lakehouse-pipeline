# %%
# List of all tables and their source files
tables = {
    "customers": "olist_customers_dataset.csv",
    "geolocation": "olist_geolocation_dataset.csv",
    "order_items": "olist_order_items_dataset.csv",
    "order_payments": "olist_order_payments_dataset.csv",
    "order_reviews": "olist_order_reviews_dataset.csv",
    "orders": "olist_orders_dataset.csv",
    "products": "olist_products_dataset.csv",
    "sellers": "olist_sellers_dataset.csv",
    "category_translation": "product_category_name_translation.csv"
}

raw_path = "/Volumes/workspace/retail_raw/olist_raw/"
bronze_path = "/Volumes/workspace/retail_raw/bronze/"

for table_name, file_name in tables.items():
    df = spark.read.csv(raw_path + file_name, header=True, inferSchema=True)
    df.write.format("delta").mode("overwrite").save(bronze_path + table_name)
    print(f"✅ Bronze loaded: {table_name} -> {df.count()} rows")
# Out:
# ✅ Bronze loaded: customers -> 99441 rows
# ✅ Bronze loaded: geolocation -> 1000163 rows
# ✅ Bronze loaded: order_items -> 112650 rows
# ✅ Bronze loaded: order_payments -> 103886 rows
# ✅ Bronze loaded: order_reviews -> 104162 rows
# ✅ Bronze loaded: orders -> 99441 rows
# ✅ Bronze loaded: products -> 32951 rows
# ✅ Bronze loaded: sellers -> 3095 rows
# ✅ Bronze loaded: category_translation -> 71 rows
